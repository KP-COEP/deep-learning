# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_text_ids = [[source_vocab_to_int[word] 
                        for _, word in enumerate(lines.split())] 
                       for _, lines in enumerate(source_text.splitlines())]
    
    target_text_ids = [[target_vocab_to_int[word] 
                        for _, word in enumerate("{} <EOS>".format(lines).split())] 
                       for _, lines in enumerate(target_text.splitlines())]
    
    return source_text_ids, target_text_ids 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# /home/ritesh_malaiya/anaconda3/envs/p3/lib/python3.6/site-packages/ipykernel/__main__.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, shape=[None, None], name='input')
    targets = tf.placeholder(tf.int32, shape=[None, None], name='targets_placeholder')
    learning_rate = tf.placeholder(tf.float32, name = 'learning_rate_placeholder')
    keep_prob = tf.placeholder(tf.float32, name = 'keep_prob')
    
    return input, targets, learning_rate, keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)

    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

    cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    
    outputs, state = tf.nn.dynamic_rnn(cell, rnn_inputs, dtype = tf.float32)
    final_state = state
    
    return final_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        dec_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)
    
    # Apply output function
    train_logits =  output_fn(train_pred)
    
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
                                                                        output_fn, encoder_state, dec_embeddings, 
                                                                        start_of_sequence_id, 
                                                                        end_of_sequence_id, 
                                                                        maximum_length - 1, vocab_size)
    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    
    output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None)
    
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    dec_cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    
    with tf.variable_scope("training_scope") as training_scope:
        training_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                                           sequence_length, training_scope, output_fn, keep_prob)
    
    with tf.variable_scope("inference_scope") as inference_scope:
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, 
                                            target_vocab_to_int["<GO>"], target_vocab_to_int["<EOS>"], sequence_length, 
                                            vocab_size, inference_scope, output_fn, keep_prob)
    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    
    embeded_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    
    processed_target = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    embeded_target = tf.nn.embedding_lookup(dec_embeddings, processed_target)

    
    encoder_state = encoding_layer(embeded_input, rnn_size, num_layers, keep_prob)
    training_logits, inference_logits = decoding_layer(embeded_target, dec_embeddings, 
                                                      encoder_state, target_vocab_size, sequence_length, 
                                                      rnn_size, num_layers, target_vocab_to_int, 
                                                      keep_prob)
    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 2
# Batch Size
batch_size = 512
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 13
decoding_embedding_size = 13
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 1

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/269 - Train Accuracy:  0.139, Validation Accuracy:  0.217, Loss:  5.880
# Epoch   0 Batch    1/269 - Train Accuracy:  0.135, Validation Accuracy:  0.217, Loss:  5.865
# Epoch   0 Batch    2/269 - Train Accuracy:  0.177, Validation Accuracy:  0.217, Loss:  5.845
# Epoch   0 Batch    3/269 - Train Accuracy:  0.138, Validation Accuracy:  0.218, Loss:  5.830
# Epoch   0 Batch    4/269 - Train Accuracy:  0.138, Validation Accuracy:  0.217, Loss:  5.812
# Epoch   0 Batch    5/269 - Train Accuracy:  0.135, Validation Accuracy:  0.217, Loss:  5.789
# Epoch   0 Batch    6/269 - Train Accuracy:  0.178, Validation Accuracy:  0.217, Loss:  5.744
# Epoch   0 Batch    7/269 - Train Accuracy:  0.179, Validation Accuracy:  0.218, Loss:  5.709
# Epoch   0 Batch    8/269 - Train Accuracy:  0.138, Validation Accuracy:  0.218, Loss:  5.691
# Epoch   0 Batch    9/269 - Train Accuracy:  0.176, Validation Accuracy:  0.218, Loss:  5.628
# Epoch   0 Batch   10/269 - Train Accuracy:  0.139, Validation Accuracy:  0.217, Loss:  5.603
# Epoch   0 Batch   11/269 - Train Accuracy:  0.178, Validation Accuracy:  0.217, Loss:  5.514
# Epoch   0 Batch   12/269 - Train Accuracy:  0.138, Validation Accuracy:  0.217, Loss:  5.485
# Epoch   0 Batch   13/269 - Train Accuracy:  0.215, Validation Accuracy:  0.217, Loss:  5.342
# Epoch   0 Batch   14/269 - Train Accuracy:  0.178, Validation Accuracy:  0.216, Loss:  5.321
# Epoch   0 Batch   15/269 - Train Accuracy:  0.175, Validation Accuracy:  0.216, Loss:  5.260
# Epoch   0 Batch   16/269 - Train Accuracy:  0.179, Validation Accuracy:  0.216, Loss:  5.167
# Epoch   0 Batch   17/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  5.104
# Epoch   0 Batch   18/269 - Train Accuracy:  0.136, Validation Accuracy:  0.216, Loss:  5.082
# Epoch   0 Batch   19/269 - Train Accuracy:  0.217, Validation Accuracy:  0.217, Loss:  4.886
# Epoch   0 Batch   20/269 - Train Accuracy:  0.139, Validation Accuracy:  0.216, Loss:  4.927
# Epoch   0 Batch   21/269 - Train Accuracy:  0.139, Validation Accuracy:  0.216, Loss:  4.859
# Epoch   0 Batch   22/269 - Train Accuracy:  0.179, Validation Accuracy:  0.216, Loss:  4.703
# Epoch   0 Batch   23/269 - Train Accuracy:  0.177, Validation Accuracy:  0.216, Loss:  4.611
# Epoch   0 Batch   24/269 - Train Accuracy:  0.137, Validation Accuracy:  0.216, Loss:  4.645
# Epoch   0 Batch   25/269 - Train Accuracy:  0.137, Validation Accuracy:  0.216, Loss:  4.564
# Epoch   0 Batch   26/269 - Train Accuracy:  0.215, Validation Accuracy:  0.215, Loss:  4.336
# Epoch   0 Batch   27/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  4.358
# Epoch   0 Batch   28/269 - Train Accuracy:  0.133, Validation Accuracy:  0.215, Loss:  4.396
# Epoch   0 Batch   29/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  4.313
# Epoch   0 Batch   30/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  4.165
# Epoch   0 Batch   31/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  4.083
# Epoch   0 Batch   32/269 - Train Accuracy:  0.173, Validation Accuracy:  0.215, Loss:  4.056
# Epoch   0 Batch   33/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.970
# Epoch   0 Batch   34/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.939
# Epoch   0 Batch   35/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.893
# Epoch   0 Batch   36/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.857
# Epoch   0 Batch   37/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  3.820
# Epoch   0 Batch   38/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.790
# Epoch   0 Batch   39/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.754
# Epoch   0 Batch   40/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.827
# Epoch   0 Batch   41/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  3.706
# Epoch   0 Batch   42/269 - Train Accuracy:  0.214, Validation Accuracy:  0.215, Loss:  3.572
# Epoch   0 Batch   43/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  3.741
# Epoch   0 Batch   44/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.621
# Epoch   0 Batch   45/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.725
# Epoch   0 Batch   46/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.737
# Epoch   0 Batch   47/269 - Train Accuracy:  0.215, Validation Accuracy:  0.215, Loss:  3.465
# Epoch   0 Batch   48/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.553
# Epoch   0 Batch   49/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  3.659
# Epoch   0 Batch   50/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.637
# Epoch   0 Batch   51/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.547
# Epoch   0 Batch   52/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.509
# Epoch   0 Batch   53/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.617
# Epoch   0 Batch   54/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  3.611
# Epoch   0 Batch   55/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.486
# Epoch   0 Batch   56/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.475
# Epoch   0 Batch   57/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.470
# Epoch   0 Batch   58/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.464
# Epoch   0 Batch   59/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.449
# Epoch   0 Batch   60/269 - Train Accuracy:  0.211, Validation Accuracy:  0.215, Loss:  3.377
# Epoch   0 Batch   61/269 - Train Accuracy:  0.215, Validation Accuracy:  0.215, Loss:  3.326
# Epoch   0 Batch   62/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  3.343
# Epoch   0 Batch   63/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.425
# Epoch   0 Batch   64/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.430
# Epoch   0 Batch   65/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.398
# Epoch   0 Batch   66/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  3.324
# Epoch   0 Batch   67/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  3.418
# Epoch   0 Batch   68/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  3.403
# Epoch   0 Batch   69/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.529
# Epoch   0 Batch   70/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.364
# Epoch   0 Batch   71/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  3.512
# Epoch   0 Batch   72/269 - Train Accuracy:  0.211, Validation Accuracy:  0.215, Loss:  3.284
# Epoch   0 Batch   73/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.372
# Epoch   0 Batch   74/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  3.481
# Epoch   0 Batch   75/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  3.367
# Epoch   0 Batch   76/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  3.400
# Epoch   0 Batch   77/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  3.345
# Epoch   0 Batch   78/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  3.361
# Epoch   0 Batch   79/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  3.363
# Epoch   0 Batch   80/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.304
# Epoch   0 Batch   81/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.341
# Epoch   0 Batch   82/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  3.308
# Epoch   0 Batch   83/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.303
# Epoch   0 Batch   84/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.320
# Epoch   0 Batch   85/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.335
# Epoch   0 Batch   86/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.335
# Epoch   0 Batch   87/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.471
# Epoch   0 Batch   88/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.303
# Epoch   0 Batch   89/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  3.282
# Epoch   0 Batch   90/269 - Train Accuracy:  0.133, Validation Accuracy:  0.215, Loss:  3.450
# Epoch   0 Batch   91/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  3.288
# Epoch   0 Batch   92/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.282
# Epoch   0 Batch   93/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  3.186
# Epoch   0 Batch   94/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.275
# Epoch   0 Batch   95/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.276
# Epoch   0 Batch   96/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  3.279
# Epoch   0 Batch   97/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.262
# Epoch   0 Batch   98/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  3.225
# Epoch   0 Batch   99/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.384
# Epoch   0 Batch  100/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  3.195
# Epoch   0 Batch  101/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.365
# Epoch   0 Batch  102/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.229
# Epoch   0 Batch  103/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.213
# Epoch   0 Batch  104/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.234
# Epoch   0 Batch  105/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.228
# Epoch   0 Batch  106/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.227
# Epoch   0 Batch  107/269 - Train Accuracy:  0.133, Validation Accuracy:  0.215, Loss:  3.373
# Epoch   0 Batch  108/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  3.215
# Epoch   0 Batch  109/269 - Train Accuracy:  0.173, Validation Accuracy:  0.215, Loss:  3.214
# Epoch   0 Batch  110/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.188
# Epoch   0 Batch  111/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.327
# Epoch   0 Batch  112/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.170
# Epoch   0 Batch  113/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  3.072
# Epoch   0 Batch  114/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  3.173
# Epoch   0 Batch  115/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  3.279
# Epoch   0 Batch  116/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.154
# Epoch   0 Batch  117/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.161
# Epoch   0 Batch  118/269 - Train Accuracy:  0.181, Validation Accuracy:  0.215, Loss:  3.105
# Epoch   0 Batch  119/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.247
# Epoch   0 Batch  120/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.264
# Epoch   0 Batch  121/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.124
# Epoch   0 Batch  122/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.101
# Epoch   0 Batch  123/269 - Train Accuracy:  0.133, Validation Accuracy:  0.215, Loss:  3.241
# Epoch   0 Batch  124/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.116
# Epoch   0 Batch  125/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.104
# Epoch   0 Batch  126/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.069
# Epoch   0 Batch  127/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.209
# Epoch   0 Batch  128/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.073
# Epoch   0 Batch  129/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.086
# Epoch   0 Batch  130/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.232
# Epoch   0 Batch  131/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.182
# Epoch   0 Batch  132/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.082
# Epoch   0 Batch  133/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.062
# Epoch   0 Batch  134/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.168
# Epoch   0 Batch  135/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  3.212
# Epoch   0 Batch  136/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.191
# Epoch   0 Batch  137/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.168
# Epoch   0 Batch  138/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.140
# Epoch   0 Batch  139/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.009
# Epoch   0 Batch  140/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.031
# Epoch   0 Batch  141/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  3.122
# Epoch   0 Batch  142/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.010
# Epoch   0 Batch  143/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.022
# Epoch   0 Batch  144/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  3.004
# Epoch   0 Batch  145/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.028
# Epoch   0 Batch  146/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  3.005
# Epoch   0 Batch  147/269 - Train Accuracy:  0.215, Validation Accuracy:  0.215, Loss:  2.888
# Epoch   0 Batch  148/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  3.022
# Epoch   0 Batch  149/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.991
# Epoch   0 Batch  150/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.992
# Epoch   0 Batch  151/269 - Train Accuracy:  0.216, Validation Accuracy:  0.215, Loss:  2.869
# Epoch   0 Batch  152/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.994
# Epoch   0 Batch  153/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.984
# Epoch   0 Batch  154/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.139
# Epoch   0 Batch  155/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  2.841
# Epoch   0 Batch  156/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.071
# Epoch   0 Batch  157/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.971
# Epoch   0 Batch  158/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.961
# Epoch   0 Batch  159/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.972
# Epoch   0 Batch  160/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.956
# Epoch   0 Batch  161/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.986
# Epoch   0 Batch  162/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.948
# Epoch   0 Batch  163/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.944
# Epoch   0 Batch  164/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.948
# Epoch   0 Batch  165/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.070
# Epoch   0 Batch  166/269 - Train Accuracy:  0.214, Validation Accuracy:  0.215, Loss:  2.799
# Epoch   0 Batch  167/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.926
# Epoch   0 Batch  168/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.956
# Epoch   0 Batch  169/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.946
# Epoch   0 Batch  170/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.927
# Epoch   0 Batch  171/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  3.052
# Epoch   0 Batch  172/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.923
# Epoch   0 Batch  173/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.913
# Epoch   0 Batch  174/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.929
# Epoch   0 Batch  175/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.936
# Epoch   0 Batch  176/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  3.043
# Epoch   0 Batch  177/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  2.818
# Epoch   0 Batch  178/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  3.023
# Epoch   0 Batch  179/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.910
# Epoch   0 Batch  180/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.901
# Epoch   0 Batch  181/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.885
# Epoch   0 Batch  182/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.890
# Epoch   0 Batch  183/269 - Train Accuracy:  0.278, Validation Accuracy:  0.215, Loss:  2.576
# Epoch   0 Batch  184/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.999
# Epoch   0 Batch  185/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.831
# Epoch   0 Batch  186/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  3.006
# Epoch   0 Batch  187/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.841
# Epoch   0 Batch  188/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.821
# Epoch   0 Batch  189/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.841
# Epoch   0 Batch  190/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.855
# Epoch   0 Batch  191/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.871
# Epoch   0 Batch  192/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.860
# Epoch   0 Batch  193/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.857
# Epoch   0 Batch  194/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.851
# Epoch   0 Batch  195/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.877
# Epoch   0 Batch  196/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.845
# Epoch   0 Batch  197/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.961
# Epoch   0 Batch  198/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.990
# Epoch   0 Batch  199/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.861
# Epoch   0 Batch  200/269 - Train Accuracy:  0.140, Validation Accuracy:  0.215, Loss:  2.930
# Epoch   0 Batch  201/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.821
# Epoch   0 Batch  202/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.845
# Epoch   0 Batch  203/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.920
# Epoch   0 Batch  204/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.938
# Epoch   0 Batch  205/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.815
# Epoch   0 Batch  206/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.948
# Epoch   0 Batch  207/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  2.714
# Epoch   0 Batch  208/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.937
# Epoch   0 Batch  209/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.923
# Epoch   0 Batch  210/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.778
# Epoch   0 Batch  211/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.792
# Epoch   0 Batch  212/269 - Train Accuracy:  0.180, Validation Accuracy:  0.215, Loss:  2.737
# Epoch   0 Batch  213/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.779
# Epoch   0 Batch  214/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.760
# Epoch   0 Batch  215/269 - Train Accuracy:  0.216, Validation Accuracy:  0.215, Loss:  2.626
# Epoch   0 Batch  216/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.915
# Epoch   0 Batch  217/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.912
# Epoch   0 Batch  218/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.886
# Epoch   0 Batch  219/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.862
# Epoch   0 Batch  220/269 - Train Accuracy:  0.211, Validation Accuracy:  0.215, Loss:  2.675
# Epoch   0 Batch  221/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.740
# Epoch   0 Batch  222/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.708
# Epoch   0 Batch  223/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.725
# Epoch   0 Batch  224/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.732
# Epoch   0 Batch  225/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.864
# Epoch   0 Batch  226/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.726
# Epoch   0 Batch  227/269 - Train Accuracy:  0.280, Validation Accuracy:  0.215, Loss:  2.404
# Epoch   0 Batch  228/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.760
# Epoch   0 Batch  229/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.708
# Epoch   0 Batch  230/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.745
# Epoch   0 Batch  231/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.838
# Epoch   0 Batch  232/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.874
# Epoch   0 Batch  233/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.725
# Epoch   0 Batch  234/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.734
# Epoch   0 Batch  235/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.706
# Epoch   0 Batch  236/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.704
# Epoch   0 Batch  237/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.689
# Epoch   0 Batch  238/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.690
# Epoch   0 Batch  239/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.683
# Epoch   0 Batch  240/269 - Train Accuracy:  0.247, Validation Accuracy:  0.215, Loss:  2.508
# Epoch   0 Batch  241/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.657
# Epoch   0 Batch  242/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.702
# Epoch   0 Batch  243/269 - Train Accuracy:  0.180, Validation Accuracy:  0.215, Loss:  2.638
# Epoch   0 Batch  244/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.679
# Epoch   0 Batch  245/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.806
# Epoch   0 Batch  246/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.667
# Epoch   0 Batch  247/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.772
# Epoch   0 Batch  248/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.668
# Epoch   0 Batch  249/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  2.556
# Epoch   0 Batch  250/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.750
# Epoch   0 Batch  251/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.643
# Epoch   0 Batch  252/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.711
# Epoch   0 Batch  253/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.667
# Epoch   0 Batch  254/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.628
# Epoch   0 Batch  255/269 - Train Accuracy:  0.216, Validation Accuracy:  0.215, Loss:  2.546
# Epoch   0 Batch  256/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.693
# Epoch   0 Batch  257/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.648
# Epoch   0 Batch  258/269 - Train Accuracy:  0.176, Validation Accuracy:  0.216, Loss:  2.655
# Epoch   0 Batch  259/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.625
# Epoch   0 Batch  260/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.740
# Epoch   0 Batch  261/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.796
# Epoch   0 Batch  262/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.631
# Epoch   0 Batch  263/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.722
# Epoch   0 Batch  264/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.723
# Epoch   0 Batch  265/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.729
# Epoch   0 Batch  266/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.610
# Epoch   0 Batch  267/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.636
# Epoch   1 Batch    0/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.718
# Epoch   1 Batch    1/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.735
# Epoch   1 Batch    2/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.636
# Epoch   1 Batch    3/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.707
# Epoch   1 Batch    4/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.719
# Epoch   1 Batch    5/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.736
# Epoch   1 Batch    6/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.551
# Epoch   1 Batch    7/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.569
# Epoch   1 Batch    8/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.695
# Epoch   1 Batch    9/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.601
# Epoch   1 Batch   10/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.675
# Epoch   1 Batch   11/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.592
# Epoch   1 Batch   12/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.677
# Epoch   1 Batch   13/269 - Train Accuracy:  0.214, Validation Accuracy:  0.215, Loss:  2.430
# Epoch   1 Batch   14/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.581
# Epoch   1 Batch   15/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.600
# Epoch   1 Batch   16/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.562
# Epoch   1 Batch   17/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.562
# Epoch   1 Batch   18/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.663
# Epoch   1 Batch   19/269 - Train Accuracy:  0.216, Validation Accuracy:  0.215, Loss:  2.447
# Epoch   1 Batch   20/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.644
# Epoch   1 Batch   21/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.683
# Epoch   1 Batch   22/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.532
# Epoch   1 Batch   23/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.511
# Epoch   1 Batch   24/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.657
# Epoch   1 Batch   25/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.654
# Epoch   1 Batch   26/269 - Train Accuracy:  0.214, Validation Accuracy:  0.215, Loss:  2.413
# Epoch   1 Batch   27/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.547
# Epoch   1 Batch   28/269 - Train Accuracy:  0.133, Validation Accuracy:  0.215, Loss:  2.707
# Epoch   1 Batch   29/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.657
# Epoch   1 Batch   30/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.540
# Epoch   1 Batch   31/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.500
# Epoch   1 Batch   32/269 - Train Accuracy:  0.173, Validation Accuracy:  0.215, Loss:  2.531
# Epoch   1 Batch   33/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.475
# Epoch   1 Batch   34/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.514
# Epoch   1 Batch   35/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.498
# Epoch   1 Batch   36/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.505
# Epoch   1 Batch   37/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.509
# Epoch   1 Batch   38/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.505
# Epoch   1 Batch   39/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.501
# Epoch   1 Batch   40/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.597
# Epoch   1 Batch   41/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.499
# Epoch   1 Batch   42/269 - Train Accuracy:  0.214, Validation Accuracy:  0.215, Loss:  2.396
# Epoch   1 Batch   43/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.563
# Epoch   1 Batch   44/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.461
# Epoch   1 Batch   45/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.587
# Epoch   1 Batch   46/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.623
# Epoch   1 Batch   47/269 - Train Accuracy:  0.215, Validation Accuracy:  0.215, Loss:  2.348
# Epoch   1 Batch   48/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.438
# Epoch   1 Batch   49/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.559
# Epoch   1 Batch   50/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.560
# Epoch   1 Batch   51/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.499
# Epoch   1 Batch   52/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.443
# Epoch   1 Batch   53/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.559
# Epoch   1 Batch   54/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.563
# Epoch   1 Batch   55/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.453
# Epoch   1 Batch   56/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.435
# Epoch   1 Batch   57/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.442
# Epoch   1 Batch   58/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.443
# Epoch   1 Batch   59/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.422
# Epoch   1 Batch   60/269 - Train Accuracy:  0.211, Validation Accuracy:  0.215, Loss:  2.384
# Epoch   1 Batch   61/269 - Train Accuracy:  0.214, Validation Accuracy:  0.215, Loss:  2.327
# Epoch   1 Batch   62/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  2.350
# Epoch   1 Batch   63/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.415
# Epoch   1 Batch   64/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.444
# Epoch   1 Batch   65/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.416
# Epoch   1 Batch   66/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  2.363
# Epoch   1 Batch   67/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.444
# Epoch   1 Batch   68/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.426
# Epoch   1 Batch   69/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.572
# Epoch   1 Batch   70/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.401
# Epoch   1 Batch   71/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.535
# Epoch   1 Batch   72/269 - Train Accuracy:  0.211, Validation Accuracy:  0.215, Loss:  2.331
# Epoch   1 Batch   73/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.408
# Epoch   1 Batch   74/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.482
# Epoch   1 Batch   75/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.397
# Epoch   1 Batch   76/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.461
# Epoch   1 Batch   77/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.395
# Epoch   1 Batch   78/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.419
# Epoch   1 Batch   79/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.409
# Epoch   1 Batch   80/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.342
# Epoch   1 Batch   81/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.406
# Epoch   1 Batch   82/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.339
# Epoch   1 Batch   83/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.352
# Epoch   1 Batch   84/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.378
# Epoch   1 Batch   85/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.404
# Epoch   1 Batch   86/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.397
# Epoch   1 Batch   87/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.548
# Epoch   1 Batch   88/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.365
# Epoch   1 Batch   89/269 - Train Accuracy:  0.180, Validation Accuracy:  0.215, Loss:  2.362
# Epoch   1 Batch   90/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.505
# Epoch   1 Batch   91/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.364
# Epoch   1 Batch   92/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.368
# Epoch   1 Batch   93/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  2.285
# Epoch   1 Batch   94/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.364
# Epoch   1 Batch   95/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.364
# Epoch   1 Batch   96/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.355
# Epoch   1 Batch   97/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.353
# Epoch   1 Batch   98/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.314
# Epoch   1 Batch   99/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.467
# Epoch   1 Batch  100/269 - Train Accuracy:  0.180, Validation Accuracy:  0.215, Loss:  2.296
# Epoch   1 Batch  101/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.456
# Epoch   1 Batch  102/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.338
# Epoch   1 Batch  103/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.331
# Epoch   1 Batch  104/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.342
# Epoch   1 Batch  105/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.350
# Epoch   1 Batch  106/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.353
# Epoch   1 Batch  107/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.470
# Epoch   1 Batch  108/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.347
# Epoch   1 Batch  109/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.330
# Epoch   1 Batch  110/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.324
# Epoch   1 Batch  111/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.462
# Epoch   1 Batch  112/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.311
# Epoch   1 Batch  113/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  2.222
# Epoch   1 Batch  114/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.311
# Epoch   1 Batch  115/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.422
# Epoch   1 Batch  116/269 - Train Accuracy:  0.176, Validation Accuracy:  0.216, Loss:  2.312
# Epoch   1 Batch  117/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.323
# Epoch   1 Batch  118/269 - Train Accuracy:  0.182, Validation Accuracy:  0.216, Loss:  2.250
# Epoch   1 Batch  119/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.390
# Epoch   1 Batch  120/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.408
# Epoch   1 Batch  121/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.301
# Epoch   1 Batch  122/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.267
# Epoch   1 Batch  123/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.417
# Epoch   1 Batch  124/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.296
# Epoch   1 Batch  125/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.282
# Epoch   1 Batch  126/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.257
# Epoch   1 Batch  127/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.391
# Epoch   1 Batch  128/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.265
# Epoch   1 Batch  129/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.294
# Epoch   1 Batch  130/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.430
# Epoch   1 Batch  131/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.364
# Epoch   1 Batch  132/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.301
# Epoch   1 Batch  133/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.276
# Epoch   1 Batch  134/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.359
# Epoch   1 Batch  135/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.435
# Epoch   1 Batch  136/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.395
# Epoch   1 Batch  137/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.378
# Epoch   1 Batch  138/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.336
# Epoch   1 Batch  139/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.235
# Epoch   1 Batch  140/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.263
# Epoch   1 Batch  141/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.312
# Epoch   1 Batch  142/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.242
# Epoch   1 Batch  143/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.280
# Epoch   1 Batch  144/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.245
# Epoch   1 Batch  145/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.268
# Epoch   1 Batch  146/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.239
# Epoch   1 Batch  147/269 - Train Accuracy:  0.215, Validation Accuracy:  0.215, Loss:  2.156
# Epoch   1 Batch  148/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.299
# Epoch   1 Batch  149/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.229
# Epoch   1 Batch  150/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.240
# Epoch   1 Batch  151/269 - Train Accuracy:  0.216, Validation Accuracy:  0.215, Loss:  2.139
# Epoch   1 Batch  152/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.252
# Epoch   1 Batch  153/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.244
# Epoch   1 Batch  154/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.381
# Epoch   1 Batch  155/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  2.116
# Epoch   1 Batch  156/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.291
# Epoch   1 Batch  157/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.244
# Epoch   1 Batch  158/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.218
# Epoch   1 Batch  159/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.233
# Epoch   1 Batch  160/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.240
# Epoch   1 Batch  161/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.251
# Epoch   1 Batch  162/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.226
# Epoch   1 Batch  163/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.233
# Epoch   1 Batch  164/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.225
# Epoch   1 Batch  165/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.312
# Epoch   1 Batch  166/269 - Train Accuracy:  0.214, Validation Accuracy:  0.215, Loss:  2.092
# Epoch   1 Batch  167/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.211
# Epoch   1 Batch  168/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.224
# Epoch   1 Batch  169/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.222
# Epoch   1 Batch  170/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.208
# Epoch   1 Batch  171/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.282
# Epoch   1 Batch  172/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.218
# Epoch   1 Batch  173/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.206
# Epoch   1 Batch  174/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.208
# Epoch   1 Batch  175/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.226
# Epoch   1 Batch  176/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.307
# Epoch   1 Batch  177/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  2.130
# Epoch   1 Batch  178/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.284
# Epoch   1 Batch  179/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.201
# Epoch   1 Batch  180/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.180
# Epoch   1 Batch  181/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.172
# Epoch   1 Batch  182/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.202
# Epoch   1 Batch  183/269 - Train Accuracy:  0.279, Validation Accuracy:  0.215, Loss:  1.931
# Epoch   1 Batch  184/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.289
# Epoch   1 Batch  185/269 - Train Accuracy:  0.180, Validation Accuracy:  0.215, Loss:  2.135
# Epoch   1 Batch  186/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.281
# Epoch   1 Batch  187/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.128
# Epoch   1 Batch  188/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.105
# Epoch   1 Batch  189/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.149
# Epoch   1 Batch  190/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.154
# Epoch   1 Batch  191/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.180
# Epoch   1 Batch  192/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.175
# Epoch   1 Batch  193/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.172
# Epoch   1 Batch  194/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.180
# Epoch   1 Batch  195/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.207
# Epoch   1 Batch  196/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.153
# Epoch   1 Batch  197/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.252
# Epoch   1 Batch  198/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.300
# Epoch   1 Batch  199/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.198
# Epoch   1 Batch  200/269 - Train Accuracy:  0.140, Validation Accuracy:  0.215, Loss:  2.231
# Epoch   1 Batch  201/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.155
# Epoch   1 Batch  202/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.177
# Epoch   1 Batch  203/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.228
# Epoch   1 Batch  204/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.237
# Epoch   1 Batch  205/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.152
# Epoch   1 Batch  206/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.272
# Epoch   1 Batch  207/269 - Train Accuracy:  0.212, Validation Accuracy:  0.215, Loss:  2.066
# Epoch   1 Batch  208/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.252
# Epoch   1 Batch  209/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.225
# Epoch   1 Batch  210/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.121
# Epoch   1 Batch  211/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.133
# Epoch   1 Batch  212/269 - Train Accuracy:  0.180, Validation Accuracy:  0.215, Loss:  2.076
# Epoch   1 Batch  213/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.115
# Epoch   1 Batch  214/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.108
# Epoch   1 Batch  215/269 - Train Accuracy:  0.216, Validation Accuracy:  0.215, Loss:  1.993
# Epoch   1 Batch  216/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.252
# Epoch   1 Batch  217/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.223
# Epoch   1 Batch  218/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.223
# Epoch   1 Batch  219/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.184
# Epoch   1 Batch  220/269 - Train Accuracy:  0.211, Validation Accuracy:  0.215, Loss:  2.041
# Epoch   1 Batch  221/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.094
# Epoch   1 Batch  222/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.061
# Epoch   1 Batch  223/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.070
# Epoch   1 Batch  224/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.093
# Epoch   1 Batch  225/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.191
# Epoch   1 Batch  226/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.083
# Epoch   1 Batch  227/269 - Train Accuracy:  0.280, Validation Accuracy:  0.215, Loss:  1.829
# Epoch   1 Batch  228/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.126
# Epoch   1 Batch  229/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.074
# Epoch   1 Batch  230/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.116
# Epoch   1 Batch  231/269 - Train Accuracy:  0.135, Validation Accuracy:  0.215, Loss:  2.185
# Epoch   1 Batch  232/269 - Train Accuracy:  0.134, Validation Accuracy:  0.215, Loss:  2.227
# Epoch   1 Batch  233/269 - Train Accuracy:  0.179, Validation Accuracy:  0.215, Loss:  2.111
# Epoch   1 Batch  234/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.100
# Epoch   1 Batch  235/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.090
# Epoch   1 Batch  236/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.079
# Epoch   1 Batch  237/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.071
# Epoch   1 Batch  238/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.074
# Epoch   1 Batch  239/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.064
# Epoch   1 Batch  240/269 - Train Accuracy:  0.247, Validation Accuracy:  0.215, Loss:  1.937
# Epoch   1 Batch  241/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.045
# Epoch   1 Batch  242/269 - Train Accuracy:  0.174, Validation Accuracy:  0.215, Loss:  2.079
# Epoch   1 Batch  243/269 - Train Accuracy:  0.180, Validation Accuracy:  0.215, Loss:  2.032
# Epoch   1 Batch  244/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.079
# Epoch   1 Batch  245/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.178
# Epoch   1 Batch  246/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.058
# Epoch   1 Batch  247/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.139
# Epoch   1 Batch  248/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.062
# Epoch   1 Batch  249/269 - Train Accuracy:  0.213, Validation Accuracy:  0.215, Loss:  1.974
# Epoch   1 Batch  250/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.118
# Epoch   1 Batch  251/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.044
# Epoch   1 Batch  252/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.110
# Epoch   1 Batch  253/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.074
# Epoch   1 Batch  254/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.038
# Epoch   1 Batch  255/269 - Train Accuracy:  0.216, Validation Accuracy:  0.215, Loss:  1.966
# Epoch   1 Batch  256/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.107
# Epoch   1 Batch  257/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.067
# Epoch   1 Batch  258/269 - Train Accuracy:  0.175, Validation Accuracy:  0.215, Loss:  2.067
# Epoch   1 Batch  259/269 - Train Accuracy:  0.178, Validation Accuracy:  0.215, Loss:  2.042
# Epoch   1 Batch  260/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.135
# Epoch   1 Batch  261/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.180
# Epoch   1 Batch  262/269 - Train Accuracy:  0.176, Validation Accuracy:  0.215, Loss:  2.045
# Epoch   1 Batch  263/269 - Train Accuracy:  0.138, Validation Accuracy:  0.215, Loss:  2.118
# Epoch   1 Batch  264/269 - Train Accuracy:  0.136, Validation Accuracy:  0.215, Loss:  2.127
# Epoch   1 Batch  265/269 - Train Accuracy:  0.137, Validation Accuracy:  0.215, Loss:  2.118
# Epoch   1 Batch  266/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.024
# Epoch   1 Batch  267/269 - Train Accuracy:  0.177, Validation Accuracy:  0.215, Loss:  2.055
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    
    return [vocab_to_int[word] 
            if word in vocab_to_int 
            else vocab_to_int["<UNK>"]  
            for word in sentence.split()
           ]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [128, 113, 208, 150, 43, 174, 57]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [66, 66, 66, 114, 114, 162, 162, 162, 162, 162, 162, 162, 162, 263, 263, 263, 263]
#   French Words: ['pousse', 'pousse', 'pousse', 'entre', 'entre', 'grosses', 'grosses', 'grosses', 'grosses', 'grosses', 'grosses', 'grosses', 'grosses', 'neige', 'neige', 'neige', 'neige']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
